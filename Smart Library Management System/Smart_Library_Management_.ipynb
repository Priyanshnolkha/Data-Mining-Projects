# %% [markdown]
# # Smart Library Management — Data Mining Project
#
# **Techniques:** Apriori, K-Means, Recommendation System
# **Dataset:** Library_Management_Dataset.xlsx
#
# This notebook is intentionally kept concise for the project presentation and viva.

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scipy>=1.16.3 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from mlxtend) (2.4.2)
# Requirement already satisfied: pandas>=2.3.3 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from mlxtend) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.8.0 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Maharshi Goswami\Cisco Packet Tracer 9.0.0\anaconda3\envs\datascience_env\Lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.5 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1. Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# 2. Load Dataset
df = pd.read_excel(r"C:\Users\Maharshi Goswami\OneDrive\Documents\Datamining\SMART LIBRARY MANAGEMENT SYSTEM\Library_Management_Dataset (1).xlsx")

print("Dataset Shape:", df.shape)
display(df.head())
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (500, 9)
#     Registration_No              Student_Name  Visit_Frequency_Per_Month  \
# 0  2022BCSE07AED001  PALLAMALA MUNI SIVA TEJA                         24
# 1  2022BCSE07AED002              N NITHIN RAJ                         11
# 2  2022BCSE07AED004    MACHIREDDY KAMAL KUMAR                          2
# 3  2022BCSE07AED005              PRINCE KUMAR                         15
# 4  2022BCSE07AED006         AFRAH FATHIMA M K                          9
#
#    Books_Borrowed  Digital_Resources_Accessed  Reading_Duration_Hours  \
# 0              12                           8                       1
# 1              14                          14                      34
# 2              10                          25                      55
# 3               4                           7                      56
# 4               5                          49                      42
#
#   Preferred_Genre Peak_Library_Hour  Reason_For_Visit
# 0      Technology              1 PM      Borrow Books
# 1      Technology             10 AM  Exam Preparation
# 2        Business             10 AM           Reading
# 3         History             10 AM             Study
# 4      Technology              9 AM  Exam Preparation
# Missing Values:
# Registration_No               0
# Student_Name                  0
# Visit_Frequency_Per_Month     0
# Books_Borrowed                0
# Digital_Resources_Accessed    0
# Reading_Duration_Hours        0
# Preferred_Genre               0
# Peak_Library_Hour             0
# Reason_For_Visit              0
# dtype: int64

# %%
# 3. Basic Data Analysis
print("Total Students:", len(df))
print("Total Books Borrowed:", df["Books_Borrowed"].sum())
print("Total Digital Resources:", df["Digital_Resources_Accessed"].sum())
print("Average Reading Hours:", round(df["Reading_Duration_Hours"].mean(), 2))

print("\nPopular Genres:")
display(df["Preferred_Genre"].value_counts().head())

print("\nPeak Library Hours:")
display(df["Peak_Library_Hour"].value_counts().head())
# Out:
# Total Students: 500
# Total Books Borrowed: 3811
# Total Digital Resources: 12518
# Average Reading Hours: 30.77
#
# Popular Genres:
# Preferred_Genre
# Science        82
# Technology     80
# History        75
# Non-Fiction    75
# Business       65
# Name: count, dtype: int64
# Peak Library Hours:
# Peak_Library_Hour
# 10 AM    68
# 9 AM     66
# 4 PM     65
# 12 PM    63
# 3 PM     63
# Name: count, dtype: int64

# %% [markdown]
# # Basic Visualization

# %%
# 4. Basic Visualizations
plt.figure(figsize=(8, 5))
df["Preferred_Genre"].value_counts().plot(kind="bar")
plt.title("Popular Genres")
plt.xlabel("Genre")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
df["Peak_Library_Hour"].value_counts().plot(kind="bar")
plt.title("Peak Library Hours")
plt.xlabel("Library Hour")
plt.ylabel("Number of Visits")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# CountPlot
sns.countplot(data=df, y="Reason_For_Visit")
plt.title("Reason for Library Visit")
plt.show()

# %%
sns.histplot(df["Books_Borrowed"], bins=10, kde=True)
plt.title("Books Borrowed Distribution")
plt.show()

# %%
sns.heatmap(df[features].corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation")
plt.show()

# %%
print("Frequent Itemsets:", len(frequent_items))
print("Association Rules:", len(rules))
# Out:
# Frequent Itemsets: 21
# Association Rules: 0

# %% [markdown]
# ## 5. Apriori Algorithm
# Find relationships between preferred genre, reason for visit and peak library hour.

# %%
# Create transactions
transactions = df[
    ["Preferred_Genre", "Reason_For_Visit", "Peak_Library_Hour"]
].astype(str)

transactions = transactions.apply(lambda x: x.str.strip())

# Convert categories into 0/1 format
basket = pd.get_dummies(transactions)

# Find frequent itemsets
frequent_items = apriori(
    basket,
    min_support=0.02,
    use_colnames=True
)

# Generate association rules
rules = association_rules(
    frequent_items,
    metric="confidence",
    min_threshold=0.10
)

rules = rules.sort_values("lift", ascending=False)

print("Top Apriori Rules:")
display(rules[["antecedents", "consequents", "support", "confidence", "lift"]].head(10))
# Out:
# Top Apriori Rules:
#                                     antecedents  \
# 151         frozenset({Peak_Library_Hour_9 AM})
# 150         frozenset({Reason_For_Visit_Study})
# 32          frozenset({Peak_Library_Hour_4 PM})
# 33         frozenset({Preferred_Genre_History})
# 110        frozenset({Peak_Library_Hour_11 AM})
# 111  frozenset({Reason_For_Visit_Borrow Books})
# 142      frozenset({Reason_For_Visit_Research})
# 143         frozenset({Peak_Library_Hour_3 PM})
# 55          frozenset({Peak_Library_Hour_3 PM})
# 54     frozenset({Preferred_Genre_Non-Fiction})
#
#                                     consequents  support  confidence      lift
# 151         frozenset({Reason_For_Visit_Study})    0.032    0.242424  1.836547
# 150         frozenset({Peak_Library_Hour_9 AM})    0.032    0.242424  1.836547
# 32         frozenset({Preferred_Genre_History})    0.032    0.246154  1.641026
# 33          frozenset({Peak_Library_Hour_4 PM})    0.032    0.213333  1.641026
# 110  frozenset({Reason_For_Visit_Borrow Books})    0.030    0.263158  1.585289
# 111        frozenset({Peak_Library_Hour_11 AM})    0.030    0.180723  1.585289
# 142         frozenset({Peak_Library_Hour_3 PM})    0.036    0.187500  1.488095
# 143      frozenset({Reason_For_Visit_Research})    0.036    0.285714  1.488095
# 55     frozenset({Preferred_Genre_Non-Fiction})    0.028    0.222222  1.481481
# 54          frozenset({Peak_Library_Hour_3 PM})    0.028    0.186667  1.481481

# %% [markdown]
# ## 6. K-Means Clustering
# Group students according to their library usage behaviour.

# %%
features = [
    "Visit_Frequency_Per_Month",
    "Books_Borrowed",
    "Digital_Resources_Accessed",
    "Reading_Duration_Hours"
]

X = df[features].copy()

# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create 3 user groups
kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

df["Cluster"] = kmeans.fit_predict(X_scaled)

# Cluster profile
profile = df.groupby("Cluster")[features].mean().round(2)

print("Cluster Profile:")
display(profile)
# Out:
# Cluster Profile:
#          Visit_Frequency_Per_Month  Books_Borrowed  \
# Cluster
# 0                            23.26            7.21
# 1                            12.99            7.57
# 2                            12.94            7.98
#
#          Digital_Resources_Accessed  Reading_Duration_Hours
# Cluster
# 0                             17.59                   17.86
# 1                             13.96                   44.04
# 2                             40.60                   29.07

# %%
# Evaluate clustering
score = silhouette_score(X_scaled, df["Cluster"])
print("Silhouette Score:", round(score, 3))
# Out:
# Silhouette Score: 0.187

# %%
inertia = []

for k in range(2, 7):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(2, 7), inertia, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(8,5))
sns.scatterplot(
    x=X_pca[:,0],
    y=X_pca[:,1],
    hue=df["Cluster"],
    palette="Set1"
)

plt.title("K-Means Clusters")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.show()

# %%
# K-Means Evaluation

from sklearn.metrics import silhouette_score

silhouette = silhouette_score(X_scaled, df["Cluster"])

print("K-Means Model Evaluation")
print("-------------------------")
print("Number of Clusters:", 3)
print("Silhouette Score:", round(silhouette, 3))
# Out:
# K-Means Model Evaluation
# -------------------------
# Number of Clusters: 3
# Silhouette Score: 0.187

# %%
# Apriori Evaluation

print("Apriori Model Evaluation")
print("-------------------------")
print("Number of Frequent Itemsets:", len(frequent_items))
print("Number of Association Rules:", len(rules))
print("Average Support:", round(rules["support"].mean(), 3))
print("Average Confidence:", round(rules["confidence"].mean(), 3))
print("Average Lift:", round(rules["lift"].mean(), 3))
# Out:
# Apriori Model Evaluation
# -------------------------
# Number of Frequent Itemsets: 97
# Number of Association Rules: 152
# Average Support: 0.026
# Average Confidence: 0.176
# Average Lift: 1.185

# %% [markdown]
# ## 7. Personalized Recommendation System
# Recommend reading resources based on a student's preferred genre.

# %%
def recommend_book(reg_no):
    student = df[df["Registration_No"] == reg_no]

    if student.empty:
        print("Student not found.")
        return

    genre = student["Preferred_Genre"].mode()[0]

    print("Student:", student["Student_Name"].iloc[0])
    print("Preferred Genre:", genre)
    print("\nRecommendation:")
    print(f"Explore more books from the {genre} genre.")
    print(f"Explore digital resources related to {genre}.")

# Example
recommend_book(df["Registration_No"].iloc[0])
# Out:
# Student: PALLAMALA MUNI SIVA TEJA
# Preferred Genre: Non-Fiction
#
# Recommendation:
# Explore more books from the Non-Fiction genre.
# Explore digital resources related to Non-Fiction.

# %% [markdown]
# ## 8. New Books Purchase Recommendation

# %%
genre_demand = df["Preferred_Genre"].value_counts().reset_index()
genre_demand.columns = ["Genre", "Demand"]

display(genre_demand)

top_genre = genre_demand.iloc[0]["Genre"]

print("Library Recommendation:")
print(f"Purchase more books from the {top_genre} genre because it has the highest student demand.")
# Out:
#          Genre  Demand
# 0      Science      82
# 1   Technology      80
# 2      History      75
# 3  Non-Fiction      75
# 4     Business      65
# 5   Literature      65
# 6      Fiction      58
# Library Recommendation:
# Purchase more books from the Science genre because it has the highest student demand.

# %%
# 9. Peak Hour Recommendation
peak_hours = df["Peak_Library_Hour"].value_counts()

print("Top Peak Hours:")
display(peak_hours.head(3))

print("Recommendation:")
print("Increase seating and staff availability during peak library hours.")
# Out:
# Top Peak Hours:
# Peak_Library_Hour
# 10 AM    68
# 9 AM     66
# 4 PM     65
# Name: count, dtype: int64
# Recommendation:
# Increase seating and staff availability during peak library hours.

# %% [markdown]
# ## 10. Final Project Findings
#
# 1. **Apriori:** Identifies combinations of genre, visit reason and peak hours.
# 2. **K-Means:** Segments students into different library-usage groups.
# 3. **Recommendation System:** Suggests books and digital resources based on preferred genre.
# 4. **Purchase Recommendation:** Helps the library prioritize high-demand genres.
# 5. **Peak-Hour Recommendation:** Helps allocate seating and staff during busy periods.
#
# **Note:** The current dataset does not contain a Department column, so department-wise utilization should not be fabricated. Add a real Department field if that dashboard visual is required.
